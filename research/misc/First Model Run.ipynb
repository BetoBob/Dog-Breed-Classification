# %% [markdown]
# Install TensorFlow v2.0

# %%
# !pip install tensorflow==2.0.0-alpha0

# %%
import tensorflow as tf
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from IPython.display import Image, display

print(tf.__version__)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# Download kaggle.json from Account > API
# !mv kaggle.json ~/.kaggle
# !kaggle competitions download -c dog-breed-identification
# !unzip labels.csv
# !unzip train
# !unzip test

# %%
base_path = ''
train_path = base_path + 'train/'
test_path = base_path + 'test/'
csv_path = base_path + 'labels.csv'

# %%
# train_dir = os.path.join(base_path, 'train')
# test_dir = os.path.join(base_path, 'stest')

# dir_list = os.listdir(test_dir)

# print(dir_list[:10])
# print(test_dir)

# %%
print(csv_path)
train_csv = pd.read_csv(csv_path)
# fnames = [train_path + fname + ".jpg" for fname in train_csv['id'].tolist()]

print(train_csv.describe())
print(train_csv.head())
# Out:
# labels.csv
#                                       id               breed
# count                              10222               10222
# unique                             10222                 120
# top     79c4b258a57fb46c58b749d093bb22ed  scottish_deerhound
# freq                                   1                 126
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %% [markdown]
# ## Top N

# %%
def top_n(n, labels, fnames):
  """
  Returns the following items:
    1. Filtered Top-N Labels 
    2. Filtered Top-N Data
    3. Map of Labels for One-Hot Encoding (list form)
    4. One-Hot Encoded Labels
  """

  # get the top_n labels
  top_n = list(labels["breed"].value_counts()[:n].axes[0])

  top_n_labels = labels[labels.breed.isin(top_n)]

  top_n_data = [fnames[i] for i in top_n_labels.index]

  return top_n_labels, top_n_data

# %%
# top_10_labels, top_10_data = top_n(10, train_csv, fnames)

# %%
# len(top_10_data)

# %%
# top_10_labels

# %%
breeds = {'affenpinscher': 98,
 'afghan_hound': 33,
 'african_hunting_dog': 31,
 'airedale': 71,
 'american_staffordshire_terrier': 108,
 'appenzeller': 21,
 'australian_terrier': 86,
 'basenji': 53,
 'basset': 116,
 'beagle': 70,
 'bedlington_terrier': 37,
 'bernese_mountain_dog': 15,
 'black-and-tan_coonhound': 45,
 'blenheim_spaniel': 18,
 'bloodhound': 35,
 'bluetick': 10,
 'border_collie': 85,
 'border_terrier': 79,
 'borzoi': 69,
 'boston_bull': 61,
 'bouvier_des_flandres': 106,
 'boxer': 66,
 'brabancon_griffon': 102,
 'briard': 14,
 'brittany_spaniel': 38,
 'bull_mastiff': 72,
 'cairn': 51,
 'cardigan': 73,
 'chesapeake_bay_retriever': 57,
 'chihuahua': 111,
 'chow': 20,
 'clumber': 97,
 'cocker_spaniel': 41,
 'collie': 65,
 'curly-coated_retriever': 94,
 'dandie_dinmont': 117,
 'dhole': 115,
 'dingo': 87,
 'doberman': 104,
 'english_foxhound': 23,
 'english_setter': 52,
 'english_springer': 107,
 'entlebucher': 84,
 'eskimo_dog': 49,
 'flat-coated_retriever': 55,
 'french_bulldog': 114,
 'german_shepherd': 36,
 'german_short-haired_pointer': 34,
 'giant_schnauzer': 43,
 'golden_retriever': 13,
 'gordon_setter': 80,
 'great_dane': 29,
 'great_pyrenees': 60,
 'greater_swiss_mountain_dog': 105,
 'groenendael': 19,
 'ibizan_hound': 50,
 'irish_setter': 12,
 'irish_terrier': 7,
 'irish_water_spaniel': 6,
 'irish_wolfhound': 113,
 'italian_greyhound': 59,
 'japanese_spaniel': 9,
 'keeshond': 24,
 'kelpie': 0,
 'kerry_blue_terrier': 89,
 'komondor': 11,
 'kuvasz': 32,
 'labrador_retriever': 83,
 'lakeland_terrier': 3,
 'leonberg': 62,
 'lhasa': 101,
 'malamute': 28,
 'malinois': 39,
 'maltese_dog': 42,
 'mexican_hairless': 46,
 'miniature_pinscher': 95,
 'miniature_poodle': 25,
 'miniature_schnauzer': 16,
 'newfoundland': 76,
 'norfolk_terrier': 63,
 'norwegian_elkhound': 75,
 'norwich_terrier': 58,
 'old_english_sheepdog': 30,
 'otterhound': 119,
 'papillon': 81,
 'pekinese': 112,
 'pembroke': 88,
 'pomeranian': 4,
 'pug': 27,
 'redbone': 1,
 'rhodesian_ridgeback': 93,
 'rottweiler': 54,
 'saint_bernard': 78,
 'saluki': 5,
 'samoyed': 68,
 'schipperke': 99,
 'scotch_terrier': 2,
 'scottish_deerhound': 17,
 'sealyham_terrier': 26,
 'shetland_sheepdog': 44,
 'shih-tzu': 67,
 'siberian_husky': 64,
 'silky_terrier': 91,
 'soft-coated_wheaten_terrier': 47,
 'staffordshire_bullterrier': 100,
 'standard_poodle': 56,
 'standard_schnauzer': 74,
 'sussex_spaniel': 110,
 'tibetan_mastiff': 90,
 'tibetan_terrier': 103,
 'toy_poodle': 40,
 'toy_terrier': 48,
 'vizsla': 96,
 'walker_hound': 118,
 'weimaraner': 92,
 'welsh_springer_spaniel': 82,
 'west_highland_white_terrier': 109,
 'whippet': 22,
 'wire-haired_fox_terrier': 8,
 'yorkshire_terrier': 77}

# %%
# fnames = [test_dir + fname for fname in dir_list]
fnames = [train_path + fname + '.jpg' for fname in train_csv['id'].tolist()]
labels = [breeds[s] for s in train_csv['breed'].tolist()]

# labels = [float(i) for i in labels]
# top_10_data
# top_10_labels.breed

train_fnames, test_fnames, train_labels, test_labels = train_test_split(fnames,
                                                                        labels,
                                                                        train_size=0.9,
                                                                        random_state=420)

# test_fnames = [test_path + fname for fname in test_csv['id'].tolist()]
# test_labels = test_csv['breed'].tolist()

# print(train_fnames[:10])
# print(labels[:10])

num_train = len(train_fnames)
num_test = len(test_fnames)

# %%
IMAGE_SIZE = 96

def _parse_fn(filename, label):
  image_string = tf.io.read_file(filename)
  image_decoded = tf.image.decode_jpeg(image_string)
  image_normalized = (tf.cast(image_decoded, tf.float32)/127.5) - 1
  image_resized = tf.image.resize(image_normalized, (IMAGE_SIZE, IMAGE_SIZE))
  return image_resized, label

# %%
# train_labels

# %%
BATCH_SIZE = 32

train_data = tf.data.Dataset.from_tensor_slices((tf.constant(train_fnames), tf.constant(train_labels))).map(_parse_fn).shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.experimental.AUTOTUNE)

val_data = tf.data.Dataset.from_tensor_slices((tf.constant(test_fnames), tf.constant(test_labels))).map(_parse_fn).batch(BATCH_SIZE).prefetch(tf.data.experimental.AUTOTUNE)

# %%
li = []
for t in test_labels:
  if t not in li:
    li.append(t)
li
# Out:
# ['kelpie',
#  'redbone',
#  'scotch_terrier',
#  'lakeland_terrier',
#  'pomeranian',
#  'saluki',
#  'irish_water_spaniel',
#  'irish_terrier',
#  'wire-haired_fox_terrier',
#  'japanese_spaniel',
#  'bluetick',
#  'komondor',
#  'irish_setter',
#  'golden_retriever',
#  'briard',
#  'bernese_mountain_dog',
#  'miniature_schnauzer',
#  'scottish_deerhound',
#  'blenheim_spaniel',
#  'groenendael',
#  'chow',
#  'appenzeller',
#  'whippet',
#  'english_foxhound',
#  'keeshond',
#  'miniature_poodle',
#  'sealyham_terrier',
#  'pug',
#  'malamute',
#  'great_dane',
#  'old_english_sheepdog',
#  'african_hunting_dog',
#  'kuvasz',
#  'afghan_hound',
#  'german_short-haired_pointer',
#  'bloodhound',
#  'german_shepherd',
#  'bedlington_terrier',
#  'brittany_spaniel',
#  'malinois',
#  'toy_poodle',
#  'cocker_spaniel',
#  'maltese_dog',
#  'giant_schnauzer',
#  'shetland_sheepdog',
#  'black-and-tan_coonhound',
#  'mexican_hairless',
#  'soft-coated_wheaten_terrier',
# ...

# %%
for x in train_data:
  print(x)
  break
# Out:
# (<tf.Tensor: id=12430, shape=(32, 96, 96, 3), dtype=float32, numpy=
# array([[[[-0.2378268 , -0.3711601 , -0.5185619 ],
#          [-0.25695208, -0.379256  , -0.5958895 ],
#          [-0.1135208 , -0.22328429, -0.5137651 ],
#          ...,
#          [-0.3379486 , -0.5967722 , -0.71441925],
#          [-0.33754084, -0.5963644 , -0.71401143],
#          [-0.29808006, -0.5569036 , -0.67455065]],
#
#         [[-0.26352122, -0.38596427, -0.5197955 ],
#          [-0.2794845 , -0.39168963, -0.58514863],
#          [-0.06580754, -0.1676866 , -0.43851864],
#          ...,
#          [-0.338112  , -0.5969356 , -0.7145826 ],
#          [-0.33737743, -0.596201  , -0.71384805],
#          [-0.32573527, -0.58455884, -0.7022059 ]],
#
#         [[-0.26384804, -0.37365195, -0.46736106],
#          [-0.29738817, -0.39616266, -0.55286205],
#          [-0.10351521, -0.18975098, -0.42451617],
#          ...,
#          [-0.36593056, -0.6247542 , -0.74240124],
# ...

# %%
print(test_fnames[0])
tf.io.read_file(test_fnames[0])
tf.io.read_file(train_fnames[0])
print(train_fnames[0])
# Out:
# train/a9b4ea005a892de1cddb16e297917426.jpg
# train/17738f5f90c73ed152991b28ea4d77ed.jpg

# %%
# Base model with MobileNetV2
IMG_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)

base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False, 
                                               weights='imagenet')
base_model.trainable = False

# %%
# Trainable classification head
maxpool_layer = tf.keras.layers.GlobalMaxPooling2D()
prediction_layer = tf.keras.layers.Dense(len(breeds), activation='softmax')

# %%
learning_rate = 0.0001

model = tf.keras.Sequential([
    base_model,
    maxpool_layer,
    prediction_layer
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=learning_rate),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# mobilenetv2_1.00_96 (Model)  (None, 3, 3, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_2 (Glob (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               153720
# ...
# Total params: 2,411,704
# Trainable params: 153,720
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
num_epochs = 30
steps_per_epoch = round(num_train)//BATCH_SIZE
val_steps = 20

# %%
for x in val_data:
    print(x)
# Out:
# (<tf.Tensor: id=10391, shape=(32, 96, 96, 3), dtype=float32, numpy=
# array([[[[-3.07914615e-01, -1.36930645e-01, -5.55353880e-01],
#          [-4.01049286e-01, -2.69229949e-01, -6.75196588e-01],
#          [-7.15813786e-02,  3.88583057e-02, -3.61532360e-01],
#          ...,
#          [-1.81477219e-01,  2.24444009e-02, -4.57621008e-01],
#          [-1.75150618e-01,  2.87709739e-02, -4.66980666e-01],
#          [-1.49660423e-01,  6.04575723e-02, -4.62990165e-01]],
#
#         [[-8.16329643e-02,  1.05621994e-01, -2.62515306e-01],
#          [-1.03875607e-01,  4.10999171e-02, -3.35125595e-01],
#          [-1.08616725e-01,  2.05346793e-02, -4.12974864e-01],
#          ...,
#          [-1.60401344e-01,  5.92065528e-02, -5.23636639e-01],
#          [-1.28370091e-01,  9.12377983e-02, -5.12683868e-01],
#          [-1.12829342e-01,  1.13357894e-01, -5.14054835e-01]],
#
#         [[-1.61496609e-01,  1.00916617e-01, -4.85003054e-01],
# ...

# %%
history = model.fit(train_data.repeat(),
                    epochs=num_epochs,
                    steps_per_epoch = steps_per_epoch,
                    validation_data=val_data.repeat(), 
                    validation_steps=val_steps)
# Out:
# Epoch 1/30
# 287/287 [==============================] - 209s 729ms/step - loss: 6.4804 - accuracy: 0.0343 - val_loss: 4.5853 - val_accuracy: 0.1000
# Epoch 2/30
# 287/287 [==============================] - 207s 721ms/step - loss: 4.5388 - accuracy: 0.1322 - val_loss: 3.3607 - val_accuracy: 0.2438
# Epoch 3/30
# 287/287 [==============================] - 203s 706ms/step - loss: 3.5783 - accuracy: 0.2309 - val_loss: 2.8199 - val_accuracy: 0.3406
# Epoch 4/30
# 287/287 [==============================] - 204s 711ms/step - loss: 3.0174 - accuracy: 0.3094 - val_loss: 2.5476 - val_accuracy: 0.3719
# Epoch 5/30
# 287/287 [==============================] - 206s 719ms/step - loss: 2.6126 - accuracy: 0.3763 - val_loss: 2.3965 - val_accuracy: 0.4000
# Epoch 6/30
# 287/287 [==============================] - 206s 719ms/step - loss: 2.3296 - accuracy: 0.4261 - val_loss: 2.2965 - val_accuracy: 0.4219
# Epoch 7/30
# ...

# %%
# !ls /content/drive/My\ Drive/dogs
# Out:
# '480 Final Project Report.gdoc'  'Colab Notebooks'	'Project Proposal.gdoc'
#  A_A				 'CSC 480 (Dog Group)'	 Research
#  Books				  data
#  CNN.ipynb			 'Data Analysis.ipynb'

# %% [markdown]
# * erroring out on the first image in the training set
#   * i'm guessing there is something off with the way the training data is processed
#   * the shape is off (the only dimensions listed are the 96 x 96 dimensions, but there are None types for the amount of images, the RGB values (should be 3) and for the labels

# %%
train_data
